# %% [markdown]
# ### This notebook is where I'll be modelling the stream particles of Boo3, to compare with Kevin's data (plotted in V_r vs. RA, and proper motions).

# %%
from galpy.orbit import Orbit
from galpy import potential
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
from matplotlib import animation
from IPython.display import HTML
from galpy.potential import MWPotential2014,ChandrasekharDynamicalFrictionForce,HernquistPotential,MovingObjectPotential
from galpy.util import conversion
from streamtools.df import streamspraydf

from stream_package.stream_package import graphics
# Out:
# /home/student04/.local/lib/python3.10/site-packages/galpy/util/bovy_conversion.py:6: FutureWarning: galpy.util.bovy_conversion is being deprecated in favor of galpy.util.conversion; all functions in there are the same; please switch to the new import, because the old import will be removed in v1.9
#   warnings.warn('galpy.util.bovy_conversion is being deprecated in favor of galpy.util.conversion; all functions in there are the same; please switch to the new import, because the old import will be removed in v1.9',FutureWarning)
#
# /home/student04/.local/lib/python3.10/site-packages/galpy/util/bovy_coords.py:6: FutureWarning: galpy.util.bovy_coords is being deprecated in favor of galpy.util.coords; all functions in there are the same; please switch to the new import, because the old import will be removed in v1.9
#   warnings.warn('galpy.util.bovy_coords is being deprecated in favor of galpy.util.coords; all functions in there are the same; please switch to the new import, because the old import will be removed in v1.9',FutureWarning)

# %%
from matplotlib.patches import Rectangle

# %%
pot = MWPotential2014
tdisrupt=5
mass = 1e7

ro = 8.
vo = 220.
to = conversion.time_in_Gyr(ro=ro, vo=vo)
mo = conversion.mass_in_msol(ro=ro, vo=vo)

sixD_pace = [209.3, 26.8, 46.5, -1.176, -0.89, 197.5]
o = Orbit(vxvv = sixD_pace, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
o.turn_physical_off()

# %%
print("My mass is:", mass, "Solar masses")
# Out:
# My mass is: 10000000.0 Solar masses

# %%
#o_lmc, oall_lmc, dtall_lmc = graphics.streamorbitslmc_acc(mass, o, tdisrupt, pot=pot, nstar=100)

# %%
plt.scatter(oall_lmc.ra(),oall_lmc.vlos())
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc.ra(),oall_lmc.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show();

plt.scatter(oall_lmc.pmra(), oall_lmc.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %%
#o_lmc2, oall_lmc2, dtall_lmc2 = graphics.streamorbitslmc_acc(mass*5, o, tdisrupt, pot=pot, nstar=100)

# %%
plt.scatter(oall_lmc2.ra(),oall_lmc2.vlos())
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc2.ra(),oall_lmc2.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show()

plt.scatter(oall_lmc2.pmra(), oall_lmc2.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %%
#o_lmc3, oall_lmc3, dtall_lmc3 = graphics.streamorbitslmc_acc(mass*10, o, tdisrupt, pot=pot, nstar=100)

# %%
plt.scatter(oall_lmc3.ra(),oall_lmc3.vlos())
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc3.ra(),oall_lmc3.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show()

plt.scatter(oall_lmc3.pmra(), oall_lmc3.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %%
#o_lmc4, oall_lmc4, dtall_lmc4 = graphics.streamorbitslmc_acc(mass*0.25, o, tdisrupt, pot=pot, nstar=100)

# %%
plt.scatter(oall_lmc4.ra(),oall_lmc4.vlos())
#plt.plot(o.ra(),o.vr(), 'ro')
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc4.ra(),oall_lmc4.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show()

plt.scatter(oall_lmc4.pmra(), oall_lmc4.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %% [markdown]
# ## Using McMillan2017 potential

# %%
from galpy.potential.mwpotentials import McMillan17
#o_lmc17, oall_lmc17, dtall_lmc17 = graphics.streamorbitslmc_acc(mass, o, tdisrupt, pot=McMillan17, nstar=100)

# %%
plt.scatter(oall_lmc17.ra(),oall_lmc17.vlos())
#plt.plot(o.ra(),o.vr(), 'ro')
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc17.ra(),oall_lmc17.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show()

plt.scatter(oall_lmc17.pmra(), oall_lmc17.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %%
from galpy.potential.mwpotentials import McMillan17
#o_lmc172, oall_lmc172, dtall_lmc172 = graphics.streamorbitslmc_acc(mass*5, o, tdisrupt, pot=McMillan17, nstar=100)

# %%
plt.scatter(oall_lmc172.ra(),oall_lmc172.vlos())
#plt.plot(o.ra(),o.vr(), 'ro')
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc172.ra(),oall_lmc172.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show()

plt.scatter(oall_lmc172.pmra(), oall_lmc172.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %%
from galpy.potential.mwpotentials import McMillan17
#o_lmc173, oall_lmc173, dtall_lmc173 = graphics.streamorbitslmc_acc(mass*0.25, o, tdisrupt, pot=McMillan17, nstar=100)

# %%
plt.scatter(oall_lmc173.ra(),oall_lmc173.vlos())
#plt.plot(o.ra(),o.vr(), 'ro')
#plt.xlim(207,213)
#plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
rect = Rectangle((207,165), 6,65,linewidth=1,edgecolor='r',facecolor='none')
ax = plt.gca()
ax.add_patch(rect)
plt.show();

plt.scatter(oall_lmc173.ra(),oall_lmc173.vlos())
plt.xlim(207,213)
plt.ylim(165,230)
plt.xlabel('RA (deg)')
plt.ylabel('Radial velocity (km/s)')
ax = plt.gca()
plt.setp(ax.spines.values(), color='red')
plt.plot(o.ra(), o.vlos(), "ro", label='Boo3');
plt.legend()
plt.show()

plt.scatter(oall_lmc173.pmra(), oall_lmc173.pmdec())
plt.plot(o.pmra(), o.pmdec(), "ro", label='Boo3')
plt.legend()
plt.xlim(-2,0)
plt.ylim(-2,0)
plt.xlabel('PMRA (mas/yr)')
plt.ylabel('PMDEC (mas/yr)')
plt.show()

# %% [markdown]
# ### Saving the data

# %%
# import pickle
# file_streams = open('lmc_stream_models.obj', 'wb')

streams_dict = {
    "MW14 1E7" : oall_lmc,
    "MW14 5*1E7" : oall_lmc2,
    "MW14 1E8" : oall_lmc3,
    "MW14 2.5*1E6" : oall_lmc4,
#    "MCM17 1E7" : oall_lmc17,
#    "MCM17 5*1E7" : oall_lmc172,
#    "MCM17 2.5*1E6" : oall_lmc173
}

# pickle.dump(streams_dict, file_streams)
# file_streams.close()

# %%
import pickle
filehandler = open('lmc_stream_models.obj', 'rb') 
obj = pickle.load(filehandler)

oall_lmc = obj.get("MW14 1E7")
oall_lmc2 = obj.get("MW14 5*1E7")
oall_lmc3 = obj.get("MW14 1E8")
oall_lmc4 = obj.get("MW14 2.5*1E6")
oall_lmc17 = obj.get("MCM17 1E7")
oall_lmc172 = obj.get("MCM17 5*1E7")
oall_lmc173 = obj.get("MCM17 2.5*1E6")

# %% [markdown]
# ### Plot generation

# %%
sixD_pace = [209.3, 26.8, 46.5, -1.176, -0.89, 197.5]

MWpotLMC = graphics.lmc_potential_wacc(tdisrupt, pot=MWPotential2014)

o_intb = Orbit(vxvv = sixD_pace, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
tsb = np.linspace(0, -1/to, 201)
o_intb.integrate(tsb, pot=MWpotLMC)
o_intf = Orbit(vxvv = sixD_pace, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
tsf = np.linspace(0, 1/to, 201)
o_intf.integrate(tsf, pot=MWpotLMC)

# McpotLMC = graphics.lmc_potential_wacc(tdisrupt, pot=McMillan17)

# o_intmcb = Orbit(vxvv = sixD_pace, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
# o_intmcb.turn_physical_off()
# o_intmcb.integrate(tsb, pot=McpotLMC)

# o_intmcf = Orbit(vxvv = sixD_pace, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
# o_intmcf.turn_physical_off()
# o_intmcf.integrate(tsf, pot=McpotLMC)
# Out:
# galpyWarning: Cannot use symplectic integration because some of the included forces are dissipative (using non-symplectic integrator dopr54_c instead)
# galpyWarning: You specified integration times as a Quantity, but are evaluating at times not specified as a Quantity; assuming that time given is in natural (internal) units (multiply time by unit to get output at physical time)

# %%
def gen_plot(ointb, ointf, oall, o):
    fig = plt.figure(figsize=(12,15))
    ax1 = fig.add_subplot(321)
    ax2 = fig.add_subplot(322)
    ax3 = fig.add_subplot(323)
    ax4 = fig.add_subplot(324)
    
    ax1.scatter(oall.ra(), oall.dec());
    ax1.plot(o.ra(), o.dec(), "ro", label='Boo3');
    ax1.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
    ax1.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
    ax1.set_xlim(213, 206)
    ax1.set_ylim(24.5, 29)
    ax1.set_title('Ra vs. Dec')
    ax1.set_xlabel('RA (deg)')
    ax1.set_ylabel('DEC (deg)')
    ax1.legend()
    ax1.minorticks_on()
    
    ax2.scatter(oall.ra(), oall.vlos());
    ax2.plot(o.ra(), o.vlos(), "ro", label='Boo3');
    ax2.plot(ointb.ra(tsb), ointb.vlos(tsb), 'k-');
    ax2.plot(ointf.ra(tsf), ointf.vlos(tsf), 'k--');
    ax2.set_xlim(213, 206)
    ax2.set_ylim(165, 230)
    ax2.set_title('Radial Velocity')
    ax2.set_xlabel('RA (deg)')
    ax2.set_ylabel('Radial Velocity (km/s)')
    ax2.legend()
    ax2.minorticks_on()
    
    ax3.scatter(oall.ra(), oall.pmra());
    ax3.plot(o.ra(), o.pmra(), "ro", label='Boo3');
    ax3.plot(ointb.ra(tsb)[:10], ointb.pmra(tsb)[:10], 'k-');
    ax3.plot(ointf.ra(tsf)[:100], ointf.pmra(tsf)[:100], 'k--');
    ax3.set_xlim(213, 206)
    ax3.set_ylim(-2, 0)
    ax3.set_title('Proper Motion (Ra)')
    ax3.set_xlabel('RA (deg)')
    ax3.set_ylabel('PMRA (mas/yr)')
    ax3.legend()
    ax3.minorticks_on()
    
    ax4.scatter(oall.ra(), oall.pmdec());
    ax4.plot(o.ra(), o.pmdec(), "ro", label='Boo3');
    ax4.plot(ointb.ra(tsb)[:10], ointb.pmdec(tsb)[:10], 'k-');
    ax4.plot(ointf.ra(tsf)[:100], ointf.pmdec(tsf)[:100], 'k--');
    ax4.set_xlim(213, 206)
    ax4.set_ylim(-2, 0)
    ax4.set_title('Proper Motion (Dec)')
    ax4.set_xlabel('RA (deg)')
    ax4.set_ylabel('PMDEC (mas/yr)')
    ax4.legend()
    ax4.minorticks_on()
    
    plt.tight_layout()
    #plt.show();

    
    
    #fig2 = plt.figure(figsize=(5,10))
    ax5 = fig.add_subplot(325)
    ax6 = fig.add_subplot(326)
    
    ax5.scatter(oall.pmra(), oall.pmdec())
    ax5.scatter(o.pmra(), o.pmdec(), c='red', label='Boo3')
    ax5.plot(ointb.pmra(tsb)[:20], ointb.pmdec(tsb)[:20], 'k-');
    ax5.plot(ointf.pmra(tsf)[:150], ointf.pmdec(tsf)[:150], 'k--');
    ax5.legend()
    ax5.set_xlim(-2,0)
    ax5.set_ylim(-2,0)
    ax5.set_title('Proper Motions')
    ax5.set_xlabel('PMRA (mas/yr)')
    ax5.set_ylabel('PMDEC (mas/yr)')
    
    ax6.scatter(oall.ra(), oall.dist());
    ax6.scatter(o.ra(), o.dist(), c='red', label='Boo3');
    ax6.plot(ointb.ra(tsb), ointb.dist(tsb), 'k-');
    ax6.plot(ointf.ra(tsf), ointf.dist(tsf), 'k--');
    ax6.set_xlim(213, 206)
    ax6.set_ylim(30,60)
    ax6.legend()
    ax6.set_title('Distance')
    ax6.set_xlabel('RA (deg)')
    ax6.set_ylabel('Distance (kpc)')
    
    ax5.minorticks_on()
    ax6.minorticks_on()
    plt.show();
    return None

# %%
for key, value in streams_dict.items():
    print(key)
    gen_plot(o_intb, o_intf, value, o)
# Out:
# MW14 1E7
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# MW14 5*1E7
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# MW14 1E8
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# MW14 2.5*1E6
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc

# %% [markdown]
# ## Running simulation with Kevin's data:

# %%
sixD_kevin_means = [209.3, 26.8, 46.5, -1.16, -0.88, 189.8]
o_k = Orbit(vxvv = sixD_kevin_means, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
o_k.turn_physical_off()

pot = MWPotential2014
tdisrupt = 5
mass = 1e7

# %%
#ok_lmc, oallk_lmc, dtallk_lmc = graphics.streamorbitslmc_acc(mass, o_k, tdisrupt, pot=pot, nstar=100)
# Out:
# galpyWarning: Cannot use symplectic integration because some of the included forces are dissipative (using non-symplectic integrator dopr54_c instead)
# galpyWarning: You specified integration times as a Quantity, but are evaluating at times not specified as a Quantity; assuming that time given is in natural (internal) units (multiply time by unit to get output at physical time)

# %%
#ok_lmc2, oallk_lmc2, dtallk_lmc2 = graphics.streamorbitslmc_acc(mass*5, o_k, tdisrupt, pot=pot, nstar=100)

# %%
#ok_lmc3, oallk_lmc3, dtallk_lmc3 = graphics.streamorbitslmc_acc(mass*0.1, o_k, tdisrupt, pot=pot, nstar=100)
# Out:
# galpyWarning: Cannot use symplectic integration because some of the included forces are dissipative (using non-symplectic integrator dopr54_c instead)
# galpyWarning: You specified integration times as a Quantity, but are evaluating at times not specified as a Quantity; assuming that time given is in natural (internal) units (multiply time by unit to get output at physical time)

# %%
MWpotLMC = graphics.lmc_potential_wacc(tdisrupt, pot=MWPotential2014)

ok_intb = Orbit(vxvv = sixD_kevin_means, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
tsb = np.linspace(0, -1/to, 201)
ok_intb.integrate(tsb, pot=MWpotLMC)
ok_intf = Orbit(vxvv = sixD_kevin_means, ro=ro, vo=vo, solarmotion = [-11.1, 24.0, 7.25], radec=True)
tsf = np.linspace(0, 1/to, 201)
ok_intf.integrate(tsf, pot=MWpotLMC)
# Out:
# galpyWarning: Cannot use symplectic integration because some of the included forces are dissipative (using non-symplectic integrator dopr54_c instead)
# galpyWarning: You specified integration times as a Quantity, but are evaluating at times not specified as a Quantity; assuming that time given is in natural (internal) units (multiply time by unit to get output at physical time)

# %%
print("Kevin's data, MW14, 1E7sm")
gen_plot(ok_intb, ok_intf, oallk_lmc, o_k)

print("Kevin's data, MW14, 5E7sm")
gen_plot(ok_intb, ok_intf, oallk_lmc2, o_k)
# Out:
# Kevin's data, MW14, 1E7sm
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# Kevin's data, MW14, 5E7sm
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc

# %%
print("Kevin's data, MW14, 1E6sm")
gen_plot(ok_intb, ok_intf, oallk_lmc3, o_k)
# Out:
# Kevin's data, MW14, 1E6sm
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc

# %%
#import pickle
#file_streams = open('lmc_stream_models_k.obj', 'wb')

streams_dict_k = {
    "K: MW14 1E7" : oallk_lmc,
    "K: MW14 5E7" : oallk_lmc2,
    "K: MW14 1E6" : oallk_lmc3
#    "MCM17 1E7" : oall_lmc17,
#    "MCM17 5*1E7" : oall_lmc172,
#    "MCM17 2.5*1E6" : oall_lmc173
}

#pickle.dump(streams_dict_k, file_streams)
#file_streams.close()

# %%
import pickle
filehandler = open('lmc_stream_models_k.obj', 'rb') 
obj = pickle.load(filehandler)

oallk_lmc = obj.get("K: MW14 1E7")
oallk_lmc2 = obj.get("K: MW14 5E7")
oallk_lmc3 = obj.get("K: MW14 1E6")

# %% [markdown]
# ## Including Kevin's star sample:

# %%
import numpy as np
import pandas as pd

data = pd.read_csv(r"boo3_sample_S5.csv",sep='\s+')

# %%
data
# Out:
#     absdev_1700d_0  absdev_1700d_0.mask  absdev_580v_0  absdev_580v_0.mask  \
# 0         0.371702                False       0.107991               False
# 1         0.047487                False       0.147358               False
# 2         0.153102                False       0.121326               False
# 3         0.261796                False       0.203424               False
# 4         0.498957                False       0.234050               False
# 5         0.135704                False       0.150080               False
# 6         0.465507                False       0.182760               False
# 7         0.312284                False       0.306515               False
# 8         0.111427                False       0.161611               False
# 9         0.250686                False       0.213907               False
# 10        0.249968                False       0.332258               False
# 11        0.129880                False       0.168803               False
# 12        0.119741                False       0.157361               False
# 13        0.066901                False       0.084868               False
# 14        0.464989                False       0.265997               False
# 15        0.295017                False       0.285015               False
# 16        0.118615                False       0.121121               False
# 17        0.169601                False       0.183703               False
# 18        0.348386                False       0.183040               False
# 19        0.019383                False       0.036219               False
# 20        0.138549                False       0.113464               False
# 21        0.122352                False       0.188991               False
# 22        0.033963                False       0.043698               False
# 23        0.233781                False       0.129463               False
# 24        0.207492                False       0.456055               False
# 25        0.027571                False       0.046240               False
#
#       alpha1   alpha16   alpha50   alpha84   alpha99  alpha_kurt  ...   ew1  \
# 0  -0.033435  0.544255  0.891108  1.113227  1.194176    0.858827  ...   NaN
# 1   0.944136  0.982067  1.001709  1.022237  1.070928    1.377276  ... -1.66
# 2   0.537478  0.739210  0.905017  1.056278  1.187325   -0.362106  ... -0.33
# 3   0.423396  0.775465  0.999499  1.146095  1.196489    0.563905  ... -0.68
# 4   0.131494  0.358996  0.538244  0.744319  1.037159   -0.039246  ... -0.40
# 5   0.614855  0.832007  1.017545  1.152678  1.196833   -0.075130  ... -0.90
# 6   0.427036  0.817771  1.028032  1.146906  1.196258    1.636585  ...   NaN
# 7   0.021760  0.491336  0.796845  1.066131  1.192841    0.085566  ... -0.26
# 8   0.197638  0.421531  0.601518  0.782383  1.071480    0.114357  ... -0.80
# 9   0.173391  0.504818  0.748476  0.999926  1.181139   -0.396628  ... -1.29
# 10 -0.147143  0.448443  0.873384  1.117473  1.194916    0.405162  ... -1.06
# 11 -0.356792 -0.149594  0.115452  0.444138  0.919529   -0.091076  ... -0.38
# 12 -0.392871 -0.312763 -0.185692 -0.032029  0.186502    0.179662  ... -0.56
# 13  0.608570  0.774275  0.942492  1.048138  1.164347   -0.385020  ... -0.84
# 14  0.129620  0.657335  0.955893  1.129038  1.195681    1.046872  ...   NaN
# 15 -0.152951  0.155357  0.422126  0.718577  1.095915   -0.275579  ... -1.64
# 16 -0.040246  0.188831  0.366752  0.514202  0.729416    0.252032  ... -0.73
# 17  0.796548  0.985702  1.104809  1.173396  1.198387    0.929024  ... -1.60
# 18  0.464262  0.705573  0.898164  1.071903  1.188233   -0.330696  ... -1.27
# 19  0.997043  1.012117  1.196754  1.199455  1.199972   -1.339139  ... -0.94
# 20  0.493008  0.567741  0.621086  0.680185  0.760746   -0.016238  ... -0.89
# 21  0.009407  0.273440  0.459811  0.655780  0.960767    0.244094  ... -0.56
# 22  1.138592  1.170127  1.187215  1.196845  1.199805    1.598508  ... -0.82
# 23  0.255753  0.701341  0.971596  1.133474  1.195347    0.727776  ... -0.63
# 24 -0.392326 -0.258215  0.094675  0.652851  1.134334   -0.612612  ... -1.05
# 25  0.461797  0.597529  0.609585  0.637331  0.805519    9.931847  ... -1.25
#
#     ew1err   ew2  ew2err   ew3  ew3err    ew    ew_err   feh_cat  feh_cat_err
# 0      NaN   NaN     NaN   NaN     NaN   NaN       NaN       NaN          NaN
# 1     0.75 -1.62    0.82 -2.25    0.79 -5.53  1.363452 -1.737335     0.532358
# 2     0.14 -1.22    0.22 -1.91    0.73 -3.46  0.775177 -2.085043     0.361710
# 3     1.00 -1.15    1.22 -0.87    1.17 -2.70  1.964001 -2.406108     0.951683
# 4     0.62 -1.08    0.96 -0.70    0.15 -2.18  1.152606 -2.539220     0.634567
# 5     0.22 -2.60    0.61 -4.42    0.30 -7.92  0.714493 -0.675752     0.293106
# 6      NaN   NaN     NaN   NaN     NaN   NaN       NaN       NaN          NaN
# 7     0.39 -1.84    1.56 -0.69    1.42 -2.79  2.145251 -2.194482     1.059581
# 8     1.10 -1.42    1.50 -1.20    1.38 -3.42  2.316117 -2.193917     1.027397
# 9     0.72 -2.43    1.17  0.00    0.00 -3.72  1.373790 -1.835977     0.630880
# 10    4.16 -2.64    3.65 -2.19    3.72 -5.89  6.668321 -0.958473     2.851647
# 11    0.40 -0.76    0.21 -0.62    0.41 -1.76  0.610082 -2.906609     0.395491
# 12    0.55 -1.15    0.67 -0.96    0.19 -2.67  0.887412 -2.440413     0.440758
# 13    0.64 -1.45    0.60 -1.52    0.13 -3.81  0.886848 -2.201760     0.383197
# 14     NaN   NaN     NaN   NaN     NaN   NaN       NaN       NaN          NaN
# 15    1.81 -1.57    0.64 -1.36    1.35 -4.57  2.346955 -1.444343     1.042511
# 16    0.99 -1.30    1.46 -1.16    1.36 -3.19  2.227398 -2.294924     1.004303
# 17    0.33 -1.27    0.29 -1.23    0.29 -4.10  0.526403 -1.963195     0.242639
# 18    0.30 -1.40    1.44 -1.01    0.27 -3.68  1.495493 -2.002160     0.668126
# 19    0.03 -1.64    0.12 -1.39    0.11 -3.97  0.165529 -2.506524     0.115051
# 20    0.10 -2.04    0.32 -1.85    0.35 -4.78  0.484665 -1.660928     0.223480
# 21    1.49 -1.06    1.67 -0.89    1.57 -2.51  2.733843 -2.582967     1.335923
# 22    0.05 -2.25    0.14 -1.45    0.17 -4.52  0.225832 -2.043530     0.130368
# 23    0.76 -1.02    0.71 -0.46    0.18 -2.11  1.055509 -2.654260     0.585680
# 24    2.38 -2.02    3.22 -1.49    2.70 -4.56  4.829368 -1.619814     2.074380
# 25    0.04 -2.42    0.17 -2.13    0.16 -5.80  0.236854 -1.662693     0.131145
#
# [26 rows x 314 columns]

# %%
ra = data.ra.to_list()
dec = data.dec.to_list()
vel = data.vel_calib.to_list()
vel_err = data.vel_calib_std.to_list()
pmra = data.pmra.to_list()
pmra_err = data.pmra_error.to_list()
pmdec = data.pmdec.to_list()
pmdec_err = data.pmdec_error.to_list()

# %%
styx_radec = pd.read_csv(r"styx_radec.csv")
styx_trace = pd.read_csv(r"styx_trace.csv")

styx_ra = styx_radec.ra.to_list()
styx_dec = styx_radec.dec.to_list()

styx_tra = styx_trace.ra.to_list()
styx_tdec = styx_trace.dec.to_list()

# %%
oall = oallk_lmc3
o = o_k
ointb = ok_intb
ointf = ok_intf



fig = plt.figure(figsize=(12,15))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)

ax1.scatter(oall.ra(), oall.dec(), c='deepskyblue', label='model');
ax1.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax1.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax1.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
ax1.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax1.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax1.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax1.set_xlim(213, 206)
ax1.set_ylim(24.5, 29)
ax1.set_title('Ra vs. Dec')
ax1.set_xlabel('RA (deg)')
ax1.set_ylabel('DEC (deg)')
ax1.legend()
ax1.minorticks_on()

ax2.scatter(oall.ra(), oall.vlos(), c='deepskyblue', label='model');
ax2.errorbar(ra, vel, yerr=vel_err, markerfacecolor='none', markeredgecolor='indigo', fmt='o', ecolor='indigo', label='data')
ax2.plot(o.ra(), o.vlos(), "ro", label='Boo3');
ax2.plot(ointb.ra(tsb), ointb.vlos(tsb), 'k-');
ax2.plot(ointf.ra(tsf), ointf.vlos(tsf), 'k--');
ax2.set_xlim(213, 206)
ax2.set_ylim(165, 230)
ax2.set_title('Radial Velocity')
ax2.set_xlabel('RA (deg)')
ax2.set_ylabel('Radial Velocity (km/s)')
ax2.legend()
ax2.minorticks_on()

ax3.scatter(oall.ra(), oall.pmra(), c='deepskyblue', label='model');
ax3.errorbar(ra, pmra, yerr=pmra_err, markerfacecolor='none', markeredgecolor='indigo', fmt='o', ecolor='indigo', label='data')
ax3.plot(o.ra(), o.pmra(), "ro", label='Boo3');
ax3.plot(ointb.ra(tsb)[:10], ointb.pmra(tsb)[:10], 'k-');
ax3.plot(ointf.ra(tsf)[:100], ointf.pmra(tsf)[:100], 'k--');
ax3.set_xlim(213, 206)
ax3.set_ylim(-2, 0)
ax3.set_title('Proper Motion (Ra)')
ax3.set_xlabel('RA (deg)')
ax3.set_ylabel('PMRA (mas/yr)')
ax3.legend()
ax3.minorticks_on()

ax4.scatter(oall.ra(), oall.pmdec(), c='deepskyblue', label='model');
ax4.errorbar(ra, pmdec, yerr=pmdec_err, markerfacecolor='none', markeredgecolor='indigo', fmt='o', ecolor='indigo', label='data')
ax4.plot(o.ra(), o.pmdec(), "ro", label='Boo3');
ax4.plot(ointb.ra(tsb)[:10], ointb.pmdec(tsb)[:10], 'k-');
ax4.plot(ointf.ra(tsf)[:100], ointf.pmdec(tsf)[:100], 'k--');
ax4.set_xlim(213, 206)
ax4.set_ylim(-2, 0)
ax4.set_title('Proper Motion (Dec)')
ax4.set_xlabel('RA (deg)')
ax4.set_ylabel('PMDEC (mas/yr)')
ax4.legend()
ax4.minorticks_on()

plt.tight_layout()
#plt.show();



#fig2 = plt.figure(figsize=(5,10))
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

ax5.scatter(oall.pmra(), oall.pmdec(), c='deepskyblue', label='model')
ax5.errorbar(pmra, pmdec, xerr = pmra_err, yerr=pmdec_err, markerfacecolor='none', 
             markeredgecolor='indigo', fmt='o', ecolor='indigo', label='data')
ax5.scatter(o.pmra(), o.pmdec(), c='red', label='Boo3')
ax5.plot(ointb.pmra(tsb)[:20], ointb.pmdec(tsb)[:20], 'k-');
ax5.plot(ointf.pmra(tsf)[:150], ointf.pmdec(tsf)[:150], 'k--');
ax5.legend()
ax5.set_xlim(-2,0)
ax5.set_ylim(-2,0)
ax5.set_title('Proper Motions')
ax5.set_xlabel('PMRA (mas/yr)')
ax5.set_ylabel('PMDEC (mas/yr)')

ax6.scatter(oall.ra(), oall.dist(), c='deepskyblue', label='model');
ax6.scatter(o.ra(), o.dist(), c='red', label='Boo3');
ax6.plot(ointb.ra(tsb), ointb.dist(tsb), 'k-');
ax6.plot(ointf.ra(tsf), ointf.dist(tsf), 'k--');
ax6.set_xlim(213, 206)
ax6.set_ylim(30,60)
ax6.legend()
ax6.set_title('Distance')
ax6.set_xlabel('RA (deg)')
ax6.set_ylabel('Distance (kpc)')
    
ax5.minorticks_on()
ax6.minorticks_on()
plt.show();
# Out:
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method vlos(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmra(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method pmdec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method pmdec(.) requires vo to be given at Orbit initialization or at method evaluation; using default vo which is 220.000000 km/s
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc

# %%
fig = plt.figure(figsize=(11,16))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax6 = fig.add_subplot(326)

ax1.scatter(oallk_lmc.ra(), oallk_lmc.dec(), c='deepskyblue', label='model');
ax1.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax1.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax1.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
ax1.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax1.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax1.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax1.set_xlim(225, 200)
ax1.set_ylim(22, 32)
ax1.set_title('Ra vs. Dec (m=1E7)')
ax1.set_xlabel('RA (deg)')
ax1.set_ylabel('DEC (deg)')
ax1.legend()

ax2.scatter(oallk_lmc.ra(), oallk_lmc.dec(), c='deepskyblue', label='model');
ax2.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax2.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax2.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
#ax2.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax2.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax2.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax2.set_xlim(275, 180)
ax2.set_ylim(10, 40)
ax2.set_title('Ra vs. Dec (m=1E7)')
ax2.set_xlabel('RA (deg)')
ax2.set_ylabel('DEC (deg)')
ax2.legend()


ax3.scatter(oallk_lmc2.ra(), oallk_lmc2.dec(), c='deepskyblue', label='model');
ax3.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax3.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax3.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
ax3.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax3.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax3.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax3.set_xlim(225, 200)
ax3.set_ylim(22, 32)
ax3.set_title('Ra vs. Dec (m=5E7)')
ax3.set_xlabel('RA (deg)')
ax3.set_ylabel('DEC (deg)')
ax3.legend()

ax4.scatter(oallk_lmc2.ra(), oallk_lmc2.dec(), c='deepskyblue', label='model');
ax4.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax4.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax4.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
#ax2.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax4.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax4.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax4.set_xlim(275, 180)
ax4.set_ylim(10, 40)
ax4.set_title('Ra vs. Dec (m=5E7)')
ax4.set_xlabel('RA (deg)')
ax4.set_ylabel('DEC (deg)')
ax4.legend()


ax5.scatter(oallk_lmc3.ra(), oallk_lmc3.dec(), c='deepskyblue', label='model');
ax5.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax5.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax5.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
ax5.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax5.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax5.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax5.set_xlim(225, 200)
ax5.set_ylim(22, 32)
ax5.set_title('Ra vs. Dec (m=1E6)')
ax5.set_xlabel('RA (deg)')
ax5.set_ylabel('DEC (deg)')
ax5.legend()

ax6.scatter(oallk_lmc3.ra(), oallk_lmc3.dec(), c='deepskyblue', label='model');
ax6.scatter(ra, dec, facecolors='none', edgecolors='indigo', label='data')
ax6.plot(o.ra(), o.dec(), "ro", label='Boo3');
ax6.plot(ointb.ra(tsb), ointb.dec(tsb), 'k-');
#ax2.plot(ointf.ra(tsf), ointf.dec(tsf), 'k--');
ax6.scatter(styx_ra, styx_dec, label='styx stream radec', c='g')
ax6.scatter(styx_tra, styx_tdec, label='styx stream trace', c='lime')
ax6.set_xlim(275, 180)
ax6.set_ylim(10, 40)
ax6.set_title('Ra vs. Dec (m=1E6)')
ax6.set_xlabel('RA (deg)')
ax6.set_ylabel('DEC (deg)')
ax6.legend()

plt.tight_layout()
# Out:
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dec(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc

# %%
import numpy as np
import pandas as pd

data = pd.read_csv(r"boo3_combined.csv",sep='\s+')

# %%
data['s5_rrl'].to_list()[23:26]
data['gaia'].to_list()[26:]

dist_kpc = data['distance_pc'].to_list()[23:]
dist_kpc = [x/1000 for x in dist_kpc]
ra_deg = data['ra'].to_list()[23:]

# %%
fig = plt.figure(figsize=(6,6))
ax6 = fig.add_subplot(111)

ax6.scatter(oallk_lmc.ra(), oallk_lmc.dist(), c='deepskyblue', label='model');
ax6.scatter(o_k.ra(), o_k.dist(), c='red', label='Boo3');
ax6.plot(ok_intb.ra(tsb), ok_intb.dist(tsb), 'k-');
ax6.plot(ok_intf.ra(tsf), ok_intf.dist(tsf), 'k--');
ax6.scatter(ra_deg, dist_kpc, facecolors='none', edgecolors='indigo', label='data')
ax6.set_xlim(213, 206)
ax6.set_ylim(30,60)
ax6.legend()
ax6.set_title('Distance')
ax6.set_xlabel('RA (deg)')
ax6.set_ylabel('Distance (kpc)')
# Out:
# galpyWarning: Method ra(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# galpyWarning: Method dist(.) requires ro to be given at Orbit initialization or at method evaluation; using default ro which is 8.000000 kpc
# Text(0, 0.5, 'Distance (kpc)')
